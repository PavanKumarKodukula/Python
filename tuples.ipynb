# %%
tup=(1,2,"hello")
print(tup*2)
print(tup[1]+2)
print(tup)
print(tup[0:2])
print(tup[0:1])
print(tup.count(1))
print(tup.index(1))
# Out:
# (1, 2, 'hello', 1, 2, 'hello')
# 4
# (1, 2, 'hello')
# (1, 2)
# (1,)
# 1
# 0

# %%
t1=()
t2= tuple()
print(type(t1),type(t2))
# Out:
# <class 'tuple'> <class 'tuple'>
