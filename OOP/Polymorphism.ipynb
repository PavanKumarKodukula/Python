# %%
class Person:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def details(self):
        return "hi"
class student(Person):
    def __init__(self,name,age,roll):
        super().__init__(name,age)
        self.roll=roll
    def details(self):
        return super().details() + " hello"
b=Person("pavan",21)
print(b.details())
c=student("sai",65,76)
print(c.details())
# Out:
# hi
# hi hello

# %%
class math:
    def add(self,x,y):
        return x+y
    def add(self,x,y,z):
        return x+y+z
    def add(self,a,b,c,d):
        return a+b+c+d
p=math().add(1,2,3,4)  
print(p)
# Out:
# 10

# %%
# method overloading through default or arbitary arguments
class math:
    def add(self,a,b,c=0,d=0):
        return a+b+c+d
m=math()
print(m.add(1,2,3,4))
print(m.add(1,2,3))
print(m.add(1,2))
# Out:
# 10
# 6
# 3

# %%
class point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

p1 = point(5, 3)
print(p1)
# Out:
# <__main__.point object at 0x00000170828AB770>

# %%
class point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __str__(self):
        return f"This point class and value is: ({self.x}, {self.y})"

p1 = point(5, 3)
print(p1)
# Out:
# This point class and value is: (5, 3)

# %%
class point:
    def __init__(self, x):
        self.x = x

    def __str__(self):
        return f"This point class and value is: ({self.x})"

p1 = point(5)
p2 = point(3)

print(p1.x + p2.x)
# Out:
# 8

# %%
class point:
    def __init__(self, x):
        self.x = x

    def __str__(self):
        return f"This point class and value is: ({self.x})"

    def __add__(self, other):
        return self.x + other.x

p1 = point(5)
p2 = point(3)

print(p1.x + p2.x)
print(p1 + p2)
# Out:
# 8
# 8

# %%
class point:
    def __init__(self, x):
        self.x = x

    def __str__(self):
        return f"This point class and value is: ({self.x})"

    def __add__(self, other):
        return str(self.x) + str(other.x)

    def __sub__(self, other):
        return self.x - other.x

p1 = point(5)
p2 = point(3)

print(p1.x + p2.x)
print(p1 + p2)
print(p1 - p2)
# Out:
# 8
# 53
# 2

# %%
class point:
    def __init__(self, x):
        self.x = x

    def __str__(self):
        return str(self.x)

    # Arithmetic Operators
    def __add__(self, other):
        return point(self.x + other.x)

    def __sub__(self, other):
        return point(self.x - other.x)

    def __mul__(self, other):
        return point(self.x * other.x)

    def __truediv__(self, other):
        return point(self.x / other.x)

    def __floordiv__(self, other):
        return point(self.x // other.x)

    def __mod__(self, other):
        return point(self.x % other.x)

    def __pow__(self, other):
        return point(self.x ** other.x)

    # Unary Operators
    def __neg__(self):
        return point(-self.x)

    def __pos__(self):
        return point(+self.x)

    def __abs__(self):
        return abs(self.x)

    # Relational Operators
    def __eq__(self, other):
        return self.x == other.x

    def __ne__(self, other):
        return self.x != other.x

    def __lt__(self, other):
        return self.x < other.x

    def __le__(self, other):
        return self.x <= other.x

    def __gt__(self, other):
        return self.x > other.x

    def __ge__(self, other):
        return self.x >= other.x


p1 = point(10)
p2 = point(3)

print("Addition:", p1 + p2)
print("Subtraction:", p1 - p2)
print("Multiplication:", p1 * p2)
print("Division:", p1 / p2)
print("Floor Division:", p1 // p2)
print("Modulus:", p1 % p2)
print("Power:", p1 ** p2)

print("Negative:", -p1)
print("Positive:", +p1)
print("Absolute:", abs(point(-10)))

print("Equal:", p1 == p2)
print("Not Equal:", p1 != p2)
print("Less Than:", p1 < p2)
print("Less Than or Equal:", p1 <= p2)
print("Greater Than:", p1 > p2)
print("Greater Than or Equal:", p1 >= p2)
# Out:
# Addition: 13
# Subtraction: 7
# Multiplication: 30
# Division: 3.3333333333333335
# Floor Division: 3
# Modulus: 1
# Power: 1000
# Negative: -10
# Positive: 10
# Absolute: 10
# Equal: False
# Not Equal: True
# Less Than: False
# Less Than or Equal: False
# Greater Than: True
# Greater Than or Equal: True
