# %%
n=input()
print(type(n))
print(n)
# Out:
# <class 'str'>
# pavan

# %%
# reading integer from user
# integer to float ,string , bool
n=int(input())
print(type(n),n)
print(float(n))
print(str(n))
print(bool(n))
# Out:
# <class 'int'> 102
# 102.0
# 102
# True

# %%
#reading float value from user
#float to int , string , book
val = float(input())
print(type(val),val)
print(int(val))
print(str(val)[:4])
print(bool(val))
# Out:
# <class 'float'> 253.515
# 253
# 253.
# True

# %%
#reading complex value
real = int(input())
imaginory = int(input())
c = complex(real,imaginory)
print(c) 
print(type(c),c)
# Out:
# (24+3j)
# <class 'complex'> (24+3j)

# %%
#reading string from user
s= input()
print(type(s),s)
print(int(s))
print(float(s))
print(list(s)) # returns list of characters
print(tuple(s))
print(set(s))
# Out:
# <class 'str'> 123423
# 123423
# 123423.0
# ['1', '2', '3', '4', '2', '3']
# ('1', '2', '3', '4', '2', '3')
# {'3', '1', '2', '4'}

# %%
s=input()
print(type(s),s)
l=list(s)
print(l[-4:5])
print(tuple(s))
print(set(s))
# Out:
# <class 'str'> hello
# ['e', 'l', 'l', 'o']
# ('h', 'e', 'l', 'l', 'o')
# {'o', 'h', 'e', 'l'}

# %%
s=input().split()
print(s)
# Out:
# ['1', '2', '3']

# %%
s=list(map(int,input().split()))
print(s)
# Out:
# [1, 2, 3]

# %%
#list to tuple,set,string
l=list(map(int,input().split()))
print(l)
print(tuple(l))
print(set(l))
s=str(l)
print(s[0])
print(s)
# Out:
# [1, 2, 3]
# (1, 2, 3)
# {1, 2, 3}
# [
# [1, 2, 3]

# %%
#read list of strings
l= list(map(str,input().split()))
print(l)
# Out:
# ['hello', 'hi', 'welcome', 'ym', 'hi']

# %%
l= input().split()
print(l)
# Out:
# ['hello', 'hi', 'welcome', 'ym', 'hi']

# %%
a=list(input())
print(a)
# Out:
# ['h', 'e', 'l', 'l', 'o', ' ', 'h', 'i', ' ', 'w', 'e', 'l', 'c', 'o', 'm', 'e', ' ', 'y', 'm', ' ', 'h', 'i']

# %%
# reading tuple of integers
t=tuple(map(int,input().split()))
print(list(t))
print(set(t))
print(str(t))
# Out:
# [1, 2, 3, 545, 878, -45, -887]
# {1, 2, 3, 545, -887, 878, -45}
# (1, 2, 3, 545, 878, -45, -887)

# %%
#reading set of integers
s=set(map(int,input().split()))
print(list(s))
print(tuple(s))
print(str(s))
# Out:
# [1, 2, 3, 545, -58, -665, 887]
# (1, 2, 3, 545, -58, -665, 887)
# {1, 2, 3, 545, -58, -665, 887}

# %%
#eval()
print("3+5")
print(3+5)
print(eval("3+5"))
# Out:
# 3+5
# 8
# 8

# %%
n=eval(input())
print(type(n),n)
# Out:
# <class 'float'> 1.23
