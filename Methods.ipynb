# %%
class Mobile:
    company="Samsung"
    def __init__(self,model,ram,rom,price):
        self.model=model
        self.ram=ram
        self.rom=rom
        self.price=price
    def about_phone(self):
        return f"the {self.model} have {self.ram} GB RAM and {self.rom} GB ROM"    
    def display():
            return "This is samsung display"
    @classmethod
    def update_company(cls,new_name):
        cls.company=new_name
        return "company name updated"
    @staticmethod
    def charger_provide(cable=False):
        return "adapter + cable" if cable else "only adapter"

Samsungs23fe = Mobile("samsung23fe",16,256,30000)
samsungs24fe = Mobile("samsung24fe",16,256,30000)
print(Samsungs23fe.about_phone())
print(samsungs24fe.charger_provide(True))
#print(Mobile.about_phone())
print(Mobile.update_company("Samsung Plus"))
print(Mobile.charger_provide())
print(Mobile.company)
# Out:
# the samsung23fe have 16 GB RAM and 256 GB ROM
# adapter + cable
# company name updated
# only adapter
# Samsung Plus

# %%
class Account:
    
    def __init__(self,username,balance,password):

        self.username=username
        self.balance=balance
        self.password=password
    def withdraw(self,amount):
        if self.balance>=amount:
            return f"{amount} withdrawal successfully"
        return "Insufficient Balance"
    def deposit(self,amount):
        self.balance+=amount
        return f"{amount} deposit successfully and current balance is {self.balance}"
user=Account("Pavan",5000,"P@123")
print(user.deposit(1000))
print(user.balance) 
user.balance=100000
print(user.withdraw(50000))  
print(user.balance)
# Out:
# 1000 deposit successfully and current balance is 6000
# 6000
# 50000 withdrawal successfully
# 100000

# %%
class Account:
    bank_name="Pavan"
    def __init__(self,username,balance,password):

        self.username=username #public
        self._balance=balance #Protected
        self.__password=password #private
    def get_balance(self):
         return self._balance
    def update_password(self,new_password):#setter method
         self.__password = new_password
         return "password updated"
    def get_password(self):#getter method
         return self.__password
    def withdraw(self,amount):
        if self._balance >= amount:
             self._balance -=amount
             return f"{amount} withdrawal successfully"
        return "Insufficient Balance"
    def deposit(self,amount):
            self._balance+=amount
            return f"{amount} deposite successfully and curr balance is {self._balance}"
    def __total_users(self):  #Private method
         return "Total users:100"
user=Account("Pavan",5000,"P@123")
print(user.username)
print(user.get_balance())
print(user.deposit(5000))
print(user.update_password("Kumar@123"))
print(user.get_password())
print(user._balance)
# to access private method
# obj._classname__methodname()
print(user._Account__total_users())
# Out:
# Pavan
# 5000
# 5000 deposite successfully and curr balance is 10000
# password updated
# Kumar@123
# 10000
# Total users:100
