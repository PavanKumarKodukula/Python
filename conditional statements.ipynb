# %%
# if else
n=int(input())
if(n>-1):
    print(f"{n} is a positive number")
else:
    print(f"{n} is a neagtive number")
# Out:
# -1 is a neagtive number

# %%
n=int(input())
if (n%3==0 and n%5==0):
    print(f"{n} is divisible by both 3 and 5")
else:
    print(f"{n} is not divisble by both 3 and 5")
# Out:
# 12 is not divisble by both 3 and 5

# %%
number=int(input())
n = number**0.5
print(n)
if n==int(n):
    print(f"{number} is a perfect square")
else:
    print(f"{number} is not a perfect square")
# Out:
# 11.090536506409418
# 123 is not a perfect square

# %%
#return index of target if target exists in list of integers otherwise return -1
lst=list(map(int,input().split()))
print(lst)
target = int(input())
print(target)
if target in lst:
    print(lst.index(target))
else:
    print(-1)
# Out:
# [1, 2, 3, 4]
# 11
# -1

# %%
#check the number is even or odd without using else block
number=int(input())
if number%2==0:
    print(f"{number} is even")
if number%2==1:
    print(f"{number} is odd")
# Out:
# 246 is even

# %%
n=int(input())
print(n)
if n%3==0 and n%5==0:
 print("Fizz,Buzz")
elif n%3==0:
 print("Fizz")
elif n%5==0:
 print("Buzz")
else:
  print(n)
# Out:
# 15
# Fizz,Buzz

# %%
numb=int(input())
if numb>=0 and numb%2==0:
    print(f"{numb} is positive even")
elif numb>0:
    print(f"{numb} is positive odd")
elif numb<0 and numb%2==0:
    print(f"{numb} is negative even")  
else:
    print(f"{numb} is negative odd")
# Out:
# -1 is negative odd

# %%
#find the smaller number among the 3 numbers
a=int(input())
b=int(input())
c=int(input())
if a<=b and a<=c:
    print(f"{a} is the smallest number")
elif b<=c:
       print(f"{b} is the smallest number")
else:
      print(f"{c} is the smallest number")
# Out:
# 1 is the smallest number

# %%
NUM = int(input())
if NUM>=0:
    if NUM%2==0:
        print(f"{NUM} is positive even")
    else:
       print(f"{NUM} is positive odd")
else:
    if NUM%2==0:
        print(f"{NUM} is negative even")
    else:
        print(f"{NUM} is negative odd")
# Out:
# -2 is negative even
