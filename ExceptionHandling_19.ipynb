# %%
# Runtime Error
arr=[10,20,30]
arr.remove(100)
print(arr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Runtime Error
#       2 arr=[10,20,30]
# ----> 3 arr.remove(100)
#       4 print(arr)
#
# ValueError: list.remove(x): x not in list

# %%
arr=[]
arr.pop()
print(arr)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 arr=[]
# ----> 2 arr.pop()
#       3 print(arr)
#
# IndexError: pop from empty list

# %%
a=10/0
print(a)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 a=10/0
#       2 print(a)
#
# ZeroDivisionError: division by zero

# %%
s="pavan"
print(int(s))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 s="pavan"
# ----> 2 print(int(s))
#
# ValueError: invalid literal for int() with base 10: 'pavan'

# %%
# exception handling block
try:
    a=int(input())
    b=int(input())
    c=a+b
    print(c)
except:
    print("something wrong in try block")
else:
    print("no exception in try block")
finally:
    print("program done")
# Out:
# 30
# no exception in try block
# program done

# %%
try:
    a=int(input())
    b=int(input())
    c=a+b
    print(c)
except:
    print("something wrong in try block")
else:
    print("no exception in try block")
finally:
    print("program done")
# Out:
# something wrong in try block
# program done

# %%
try:
    a=10
    b=0
    c=a/b
    print(c)
except Exception as e:
    print(f"something wrong in try block:{e}")
# Out:
# something wrong in try block:division by zero

# %%
try:
    a=10
    b=0
    c=a/b
    print(c)
except ZeroDivisionError as e:
    print(f" Zero division not possible : {e}")
except IndexError as e:
    print(f"we cant access elemnt at this position : {e}")  
except Exception as e:
    print(f"something wrong in try block:{e}")
# Out:
#  Zero division not possible : division by zero

# %%
try:
    a=[1,2,3,4]
    b=arr[4]
    print(c)
    print(c)
except ZeroDivisionError as e:
    print(f" Zero division not possible : {e}")
except IndexError as e:
    print(f"we cant access elemnt at this position : {e}")  
except Exception as e:
    print(f"something wrong in try block:{e}")
# Out:
# we cant access elemnt at this position : list index out of range

# %%
try:
    a=10
    print(len(a))
except ZeroDivisionError as e:
    print(f" Zero division not possible : {e}")
except IndexError as e:
    print(f"we cant access elemnt at this position : {e}")  
except Exception as e:
    print(f"something wrong in try block:{e}")
# Out:
# something wrong in try block:object of type 'int' has no len()

# %%
try:
    a=10
    print(len(a))
except ZeroDivisionError as e:
    print(f" Zero division not possible : {e}")
except IndexError as e:
    print(f"we cant access elemnt at this position : {e}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 6
#       2     a=10
#       3     print(len(a))
#       4 except ZeroDivisionError as e:
#       5     print(f" Zero division not possible : {e}")
# ----> 6 except IndexError as e:
#       7     print(f"we cant access elemnt at this position : {e}")
#       8
#       9
#
# TypeError: object of type 'int' has no len()
